# %%
import os
from pathlib import Path
from operator import itemgetter
import pickle
import pydicom
from time import time
import pandas

import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Polygon, MultiPolygon, LineString, GeometryCollection, Point, MultiPoint
from shapely.affinity import translate

from catch_converter.parse_contours import parse_cvi42ws
from LazyLuna.Mini_LL import *
from LazyLuna.CATCH_utils import *
from LazyLuna.Figures import *

# %%
# basepaths
bp        = r'C:\Users\GAMMA\Desktop\THadler\Trainees'
bp_annos1 = r'C:\Users\GAMMA\Desktop\THadler\Trainees\Al.K.25.11.2021'
bp_cases  = r'C:\Users\GAMMA\Desktop\THadler\Trainees\Cases'
bp_imgs   = r'C:\Users\GAMMA\Desktop\THadler\Trainees\Imgs'

# %%
parse_cvi42ws(bp_annos1, bp_annos1, process=True, debug=False)
# Out:
# Found a total of 1408 UIDs in 177_NamelessNick202001131036021.2.276.0.7230010.3.1.2.1565852243.4476.1582545284.3497
#    Collected 30 Contours/Points for 15 different Series Subinstance UIDs
#    Done parsing Workspace - took 0.03789687156677246 Seconds.
#
# Found a total of 1394 UIDs in 177_NamelessNick_LVMA202001131036021.2.276.0.7230010.3.1.2.2984217738.4584.1586945896.16647
#    Collected 81 Contours/Points for 22 different Series Subinstance UIDs
#    Done parsing Workspace - took 0.046875 Seconds.
#
# Found a total of 1574 UIDs in 178_NamelessNick202001130940391.2.276.0.7230010.3.1.2.1565852243.4476.1582545423.4969
#    Collected 28 Contours/Points for 14 different Series Subinstance UIDs
#    Done parsing Workspace - took 0.033908843994140625 Seconds.
#
# Found a total of 1580 UIDs in 178_NamelessNick_LVMA202001130940391.2.276.0.7230010.3.1.2.2984217738.4584.1586945971.18103
#    Collected 73 Contours/Points for 20 different Series Subinstance UIDs
# ...
